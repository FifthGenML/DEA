# %%
import numpy as np
from PIL import Image
from model import DEAttack

# Load your wolf image
image = np.array(Image.open("downloaded_artifacts/reference.png"))

# Create and run attack
attack = DEAttack(image)
# attack.population
attack.attack(max_generations=100)
# Out:
# Starting Differential Evolution Attack...
# [0.2449570745229721, 'timber wolf']
# Initial API prediction: timber wolf
#
# Generation 1/100
# ----------------------------------------
# MobileNetV2 Predictions:
#   - Images predicted as wolf: 0/50 (0.0%)
#   - Wolf probability: min=0.018, avg=0.202, max=0.492
#  New best fitness: 0.018
# <PIL.Image.Image image mode=RGB size=224x224>
#  Checking best candidate with API...
# [0.07247000932693481, 'timber wolf']
# API Prediction: timber wolf
# using new
#
# Generation 2/100
# ----------------------------------------
# MobileNetV2 Predictions:
#   - Images predicted as wolf: 0/50 (0.0%)
#   - Wolf probability: min=0.003, avg=0.025, max=0.100
#  New best fitness: 0.003
# <PIL.Image.Image image mode=RGB size=224x224>
#  Checking best candidate with API...
# [0.0739465281367302, 'tick']
# API Prediction: tick
#
#  Attack succeeded at generation 2!
# Final API prediction: tick
# array([[[135,  38,  95],
#         [ 76, 255,  54],
# ...
